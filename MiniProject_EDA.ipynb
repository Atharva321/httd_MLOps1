# %% [markdown]
# <a href="https://colab.research.google.com/github/Atharva321/httd_MLOps1/blob/master/MiniProject_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import plotly as pt
import matplotlib  as mt

# %%
data = pd.read_csv("/content/drive/My Drive/tmdb-movies (1) (1).csv")

# %%
data
# Out:
#            id    imdb_id  popularity  ...  release_year    budget_adj   revenue_adj
# 0      135397  tt0369610   32.985763  ...          2015  1.379999e+08  1.392446e+09
# 1       76341  tt1392190   28.419936  ...          2015  1.379999e+08  3.481613e+08
# 2      262500  tt2908446   13.112507  ...          2015  1.012000e+08  2.716190e+08
# 3      140607  tt2488496   11.173104  ...          2015  1.839999e+08  1.902723e+09
# 4      168259  tt2820852    9.335014  ...          2015  1.747999e+08  1.385749e+09
# ...       ...        ...         ...  ...           ...           ...           ...
# 10861      21  tt0060371    0.080598  ...          1966  0.000000e+00  0.000000e+00
# 10862   20379  tt0060472    0.065543  ...          1966  0.000000e+00  0.000000e+00
# 10863   39768  tt0060161    0.065141  ...          1966  0.000000e+00  0.000000e+00
# 10864   21449  tt0061177    0.064317  ...          1966  0.000000e+00  0.000000e+00
# ...

# %%
import numpy as np

# %%
max(data['revenue'])
# Out:
# 2781505847

# %%
data.isna().sum()
# Out:
# id                         0
# imdb_id                   10
# popularity                 0
# budget                     0
# revenue                    0
# original_title             0
# cast                      76
# homepage                7930
# director                  44
# tagline                 2824
# keywords                1493
# overview                   4
# runtime                    0
# genres                    23
# production_companies    1030
# release_date               0
# vote_count                 0
# vote_average               0
# release_year               0
# budget_adj                 0
# revenue_adj                0
# dtype: int64

# %%
data.fillna(0)
# Out:
#            id    imdb_id  popularity  ...  release_year    budget_adj   revenue_adj
# 0      135397  tt0369610   32.985763  ...          2015  1.379999e+08  1.392446e+09
# 1       76341  tt1392190   28.419936  ...          2015  1.379999e+08  3.481613e+08
# 2      262500  tt2908446   13.112507  ...          2015  1.012000e+08  2.716190e+08
# 3      140607  tt2488496   11.173104  ...          2015  1.839999e+08  1.902723e+09
# 4      168259  tt2820852    9.335014  ...          2015  1.747999e+08  1.385749e+09
# ...       ...        ...         ...  ...           ...           ...           ...
# 10861      21  tt0060371    0.080598  ...          1966  0.000000e+00  0.000000e+00
# 10862   20379  tt0060472    0.065543  ...          1966  0.000000e+00  0.000000e+00
# 10863   39768  tt0060161    0.065141  ...          1966  0.000000e+00  0.000000e+00
# 10864   21449  tt0061177    0.064317  ...          1966  0.000000e+00  0.000000e+00
# ...

# %%
sum(data.duplicated())
# Out:
# 1

# %%
data['release_date'] = pd.to_datetime(data['release_date'])
data['release_date'].head()
# Out:
# 0   2015-06-09
# 1   2015-05-13
# 2   2015-03-18
# 3   2015-12-15
# 4   2015-04-01
# Name: release_date, dtype: datetime64[ns]

# %%
data.drop(['budget_adj','revenue_adj','overview','imdb_id','homepage','tagline'],axis =1,inplace = True)

# %%
budget.sort()

print("Third lowest: ", budget[2])
print("Third Highest: ", budget[len(budget)-2])

# %%
budget = np.array(data['budget'])

# %%
data['original_title']
# Out:
# 0                      Jurassic World
# 1                  Mad Max: Fury Road
# 2                           Insurgent
# 3        Star Wars: The Force Awakens
# 4                           Furious 7
#                      ...
# 10861              The Endless Summer
# 10862                      Grand Prix
# 10863             Beregis Avtomobilya
# 10864          What's Up, Tiger Lily?
# 10865        Manos: The Hands of Fate
# Name: original_title, Length: 10866, dtype: object

# %%
data['words'] = [len(x.split()) for x in data["original_title"].tolist()]
data['words']
# Out:
# 0        2
# 1        4
# 2        1
# 3        5
# 4        2
#         ..
# 10861    3
# 10862    2
# 10863    2
# 10864    4
# 10865    5
# Name: words, Length: 10866, dtype: int64

# %%
allwords = data

# %%
allwords = allwords[allwords["release_year"]>2000 ] 
allwords = allwords[  allwords["release_year"]<2005]

# %%
avg = sum(allwords["words"])/len(allwords["words"])
avg
# Out:
# 2.8731751824817517

# %%
allwords
# Out:
#           id  popularity     budget  ...  vote_average release_year words
# 2633     120    8.575419   93000000  ...           7.8         2001    10
# 2634     671    8.021423  125000000  ...           7.2         2001     6
# 2635    1018    4.436367   15000000  ...           7.4         2001     2
# 2636     141    3.851009    6000000  ...           7.5         2001     2
# 2637     585    3.204295  115000000  ...           7.3         2001     2
# ...      ...         ...        ...  ...           ...          ...   ...
# 7264    1843    0.006346          0  ...           6.8         2004     1
# 7265   59474    0.003461          0  ...           6.7         2004     6
# 7266  102341    0.003456          0  ...           5.2         2004     5
# 7267  203766    0.001531          0  ...           7.0         2004     3
# 7268    1392    0.001117     350000  ...           6.4         2004     3
#
# [1096 rows x 16 columns]

# %%
data[data["genres"][0]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Action|Adventure|Science Fiction|Thriller'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-67-ac43c2790344> in <module>()
# ...
